# %% [markdown]
# ## Index
# ### [Technical Questions](#technical)
# ### [Behavioural Questions](#behavioral)

# %% [markdown]
# Decided to create a question bank for all the questions that I have come across in several interviews over the last few months, for the positions Data Scientist, Data Analyst/Lead Data Analyst, and Applied Scientist.

# %% [markdown]
# ## Technical
# <a id='technical'></a>
#
# ### Machine Learning
# 1. What is your favorite algorithm?  Why? Can you explain the basic gist of it to me?
# Explain Supervised Learning versus Unsupervised Learning, and provide the name of an algorithm one could use for each.
#
# 3.
# Explain what linear regression is, and use a real-world example.
# Assumptions:
# Normally distributed - N(0,sigma2)
# No Hetersckedasticity - constant variance
# No multicollinearity - independent of eo
# Linear relationship
#
# 4.
# What are some ways that I can make my model more robust to outliers?
#
# 5.
# What is the role of trial and error in data analysis? What is the value in making a hypothesis before diving in?
#
# 6.
# Explain what a confidence interval means to someone who knows nothing about statistics or data science.  How do you interpret a confidence interval?
#
# 7.
# What is your favorite algorithm?  Why? Can you explain the basic gist of it to me?
#
# 8.
# You are consulting MGH’s senior management and outreach team, and you want to test the hypothesis that a greater number of photographs in marketing materials increases the chances that potential clients choose MGH over BI and BWH. How would you test this hypothesis?
#
# 9.
# What are the different types of joins and what are the differences between them?
#
#
# 10.
# What has been your favorite course in your degree program thus far, and why?
#
# 11.
# Can you explain the idea behind big-O notation, and why we care about it in Data Science?
#
# 12.
# Discuss together what you deem to be the basic business concepts a data science job candidate would need to know (Marketing? Sales? Margins?).
#
#
# 13.
# What basic statistics concepts have you been asked on an interview? Pick several and practice as a group.
#
# 14.
# Pick the easiest interview question you have faced, and mock-interview this around the group.
#
# 15.
# Pick the toughest interview question you have faced, and mock-interview this around the group.
#
# 16.
# Consider any question from:
# https://docs.google.com/spreadsheets/d/1sBUNmO73G9mK-R_kwz2IydJhkouJMgfixoD1FwRNikk/edit?usp=sharing
#
# 17.
# How would you tell your story? (perhaps some remember Ahsan Hhuda’s advice from Pfizer (in 2021!)--humanize yourself) How did you get to where you are today? What were some of your turning points along the way? Failures? Inspirations?
#
# 18.
# How do you define innovation in the health industry as it relates to machine learning and AI? How would you leverage technical skills in ML and AI to create successful outcomes in healthcare business (Pharma, Biotech, Consulting, Digital, etc?)--feel free to pick one area and develop an example.
#
# 19.
# How would you create a predictive model for a rare outcome?
#
#
# 20.
# What is the formula for the Pearson correlation coefficient?
#
#
# 21.
# How would you choose the set of hyper-parameters for your model?
#
# 22.
# Tell me about a project you worked on in the past and what you liked about it. Do you feel it was a successful project, and why/why not?
#
#
# 23.
# What is a p-value? What assumptions do you make to use a t-test?
#
#
# 24.
# How do you deal with over-fitting problems? What are some analysis approaches that are prone to overfitting and what are some analysis approaches that may help to avoid overfitting?
#
#
# 25.
# Tell me about a group project you're currently working on in school.
#
#
# 26.
# Tell me about a SOTA data science model or recent publication you are excited about.
#
#
# 27.
# Describe a tough technical situation you were in and how you solved it.
#
#
# 28.
# What do you think is a good starting salary for you to earn working here?
#
#
# 29.
# Is there anything about you on your resume/CV that you’d especially like me to know about?
#
#
# 30.
# Is there anything about you NOT on your resume/CV that you’d especially like me to know about?
#
#
# 31.
# How would you (quickly) sort through a large number of features to extract the most important ones?
#
#
# 32.
# What are some packages in R and Python that can be used for data wrangling?
#
#
# 33.
# Can you describe what a black box model is and provide an example?
#
#
# 34.
# Please describe the most ‘famous’ survival model and how we would interpret its coefficient estimates?
#
#
# 35.
# How would you describe the logistic regression model, and its interpretation, to a colleague who does not have any statistical or DS background?
#
#
# 36.
# Describe KNN and why we would want to use it.
#
#
# 37.
# What is the difference between regression and classification?
#
#
# 38.
# Describe the random forest (RF) method and why we would want to use it.
# What are the advantages of linear regression over RF?
#
#
# 39.
# What are the defining assumptions of Linear Models.
# How about Generalized linear models?
#
#
# 40.
# What is single value decomposition (SVD) and why would we use it?
#
#
# 41.
# Can you describe any experience you’ve had with the bioinformatics pipeline?
#
#
# 42.
# Can you describe three statistical models, the type of outcome variable they are designed to model and their underlying assumptions? Please provide once example of why or when you would NOT want to use each of these models.
#
#
# 43. How will you evaluate the performance of a model which was trained on imabalanced data
# 44. Difference between covariance and correlation
# 45. Explain p-values in layman terms
# 46. Boosting in classification
# 47. How will you make your model more robust to outliers
# 48. Why does L1 regularization produce sparse coefficients
# 	Something to do with differentiation and updating weights during gradient descent
# 49. What is entropy and information gain in the decision tree context?
# Entropy:  - p1*log2(p1) - p2*log2(p2)
# Information Gain -
# 50. Explain decision tree and random forest in layman terms.
# 51. AB Testing and how do you select appropriate number of samples for an experiment.
# 52. Lasso and Ridge, type I and type II error
# 53.
#
# ### Deep Learning
#
#
# ### Statistics

# %% [markdown]
# ## Behavioral
# <a id='behavioral'></a>
#
# I am providing answers to some of the questions

# %% [markdown]
# Tell me about a time you had a conflict with a co-worker/deal with a difficult co-worker.
#
# I was working as part of a team on an important project for an Australia based MNC and none of my team members had experience working with unstructured/text data so I was leading the team in terms of deciding the next steps and delegating tasks. And a team member was constantly late with completing their tasks.
#
# Their lateness was starting to hinder the progress of the team, and so I decided to speak
# to them in private about the issue. When I spoke to them, they became defensive and slightly confrontational. They
# said they were busy, and they were working as fast as they could.
#
# I explained in a calm and positive manner that we really needed their help with getting
# the project completed, and their particular task was slowing up the completion of the
# project. I asked them if there were any Bottlenecks that they were facing and offered to assist them in their tasks
#
# Following the conversation, they were able to complete their tasks well on time and I thanked them for being proactive in acting on the feedback. We were able to finish the project well in time. In fact that project went on to be one of the most impactful for the company that quarter. our team won the spot award which is given to 2-3 teams in the company every quarter for the impact that they made.
#
#
# How do you communicate to non-technical stakeholders
# Tailoring your communication style to suit the needs and level of understanding of the stakeholders is an essential skill to have for a data scientist. There are a couple of steps I take to ensure success while working with non-technical stakeholders.
#
# 1. Use storytelling - I will make them understand the context and business implications of our work. Explain the problem you were trying to solve, the methods you used to solve it, and the plausible business implications of those methods.
# 2. Explaining the analysis methodology in plain words without technical jargons, using analogies and examples.
# 3. Use charts, graphs, and other visual aids to help non-technical stakeholders understand how they relate to the overall business objective
# 4. Ask for feedback: Engage your audience by asking for their feedback and input. This will help ensure that your message is understood and that you are meeting the needs of your stakeholders.
#
#
# Examples - Recommender system - documents represented as vectors - can be thought of as two points in the 3-dimensional space and calculating the distance between
#
#
#
# Tell me about a project you’re proud of. / Tell me about a time you used data science to make an impact on the business.
# As a data scientist I have worked on many impactful data projects, one that stand out is -
# Recommender system:
# S - I was working with a fortune 100 company to develop a recommendation engine. For context, this comp sells networking hardware devices and whenever their customers faced a problem, they can go online and type in the problem they are facing and open a service request. And customer engineers would spend 2-3 hours researching for past similar service requests.
# T - We used text data of 7.8 M past SRs and developed an information retrieval system which recommends past 10 similar SRs.
# The intuition behind the method is that we find the minimum “traveling distance” between documents, in other words the most efficient way to “move” the distribution of document 1 to the distribution of document 2.
# A - We leveraged NLP algorithms such as word2vec and fasttext to convert NLP algorithms
# R - This resulted in a 50% decrease in the research time, led to shorter turnaround time and better customer experience.
#
# Challenge
# - developing the cleaning pipeline for the data
# - Developing metrics to evaluate the performance of the model
# - Large dataset - had to write efficient numpy we computed the similarity metric between all documents.
#
# Metrics used for this project:
# - Ranked relevance quality indicator: how well the model ranks the documents based on relevance
# - Semantic relevance quality indicator: how well the model is able to create semantic separation between
#
#
#
#
#
# Tell me about a time when you got contrary insights from data during your career and how did you communicate to stakeholders.
# Turf rebate- water savings program
# But people started watering more often to maintain the plants for a long time.
# Which led to contrary results to what we were expecting.
#
#
#
# Elevator pitch/Tell me about yourself:
#
# I recently graduated from the master’s in Health Data Science program at Harvard School of Public Health with 2+ years of experience as a Data Scientist in the industry. I interned as a data scientist at Meta past summer. I also hold a bachelor's degree in Statistics and have gained extensive experience working in cross functional teams to solve business challenges using data across different industries.
#
# Throughout my career, I have worked on the full life cycle of data projects, including understanding business problems, designing data analysis pipelines, writing SQL queries, creating reports and visualizations, and communicating insights to stakeholders.
#
# Overall, I have strong quantitative skills and leadership abilities, and a passion for learning something new every day.
#
#
# As a data scientist with a Master's from Harvard and two years of experience, I have a strong foundation in statistical analysis and machine learning. I'm skilled at developing and implementing data-driven solutions to a wide range of problems, from predicting customer behavior to optimizing business processes. I'm confident that my skills and experience make me an asset to your team.
#
# Why do you want to work at CRICO and at this role?
# I am excited about the opportunity to work at CRICO because they are not only a leader in the field of medical professional liability insurance and have a strong focus on patient safety - which sets them apart. I am particularly impressed with their use of innovative technological solutions, such as Candello, which consists of about 1/3 rd of all malpractice cases in US,  - and I am really excited to use such datasets to identify patterns in medical error and reduce preventable errors. [I was recently reading an article about how researchers in BCH used candello data to identify link b/w patient handoff failures and malpractice cases.]
#
# In addition to my answer, I personally really resonate with CRICO’s mission of providing safest care environment for patients and doctors. And I am really excited about the prospect of using my skills towards this mission.
# The leadership at CRICO is very supportive and I know winnie, I spoke to her before I started my MASTERs program at Harvard and I know that she is a very welcoming and knowledgeable leader and I would get ample of opportunities and mentorship under her to excel and grow in this role.
#
# Why do you want to work at MAIDAP?
# MAIDAP is the most extraordinary opportunity that I have come across. This two-year rotation program consists of 4 different 6-month-long projects. And I am really excited about the prospect of being able to work with various Microsoft product and research teams. I would get to work on the bleeding edge of AI and help teams launch AI-enhanced products which will impact billions of end users. The impact that my work drives is a big motivator for me and something that I seek in all opportunities.
#
# Additionally, the goal of this program is to create the next generation of AI leaders. And My long-term career goal is to take on a leadership role in the field of data science. So this program perfectly aligns with my goals and aspirations.
#
# This is the next best step for my career.
#
#
# Questions that you might have
# What questions do you have?
#
# Q. In recent years, Microsoft has doubled down on its efforts to create breakthrough AI. And has collaborated with OPENAI and enabled the release of GPT-4, which has taken the world by storm.
# How has this affected the MAIDAP program, how has it changed in the past one year and how will it change the kind of projects that you do at MAIDAP?
#
# Q. How it's preparing its members to work on cutting-edge AI projects, how does it ensure its employees are on top of all the latest advancements happening in the field?
#
# Q. The program is 2 years long and consists of 4 different 6-month long projects with various Microsoft product and research teams. So I am really curious to learn about what are some of the success metrics by which candidates are judged? What happens at the end of 2 years (when the duration of the program ends).
#
# Q. What does the onboarding process look like for this role? Is there any training in place for the candidate to complete?
#
# Q. What would be your top 2 favorite things about working at Microsoft and would you suggest a new grad to start their career with Microsoft, if yes, why?
#
# What are metrics used to measure success for this role?
# What are the facilities provided by the company to keep learning -  Statistics/data science is an ever evolving field and there are new advancements coming up every, does the company provide access to conferences, workshops so that the person in this role is always up to date with the latest advancements.
# What is the difference between the Comparative Benchmarking System and Candello?
#
#
# Why do you want to be a manager?
#
# I have extensive experience of working in the full life-cycle of data projects in the different industries. This cross-sectoral experience as a data scientist combined with my education have helped me develop a strong analytical mindset combined with business acumen.
# I am able to identify opportunities in the business where analytics/data science can make a huge difference.
# I am able to effectively formulate an analytical or data science problem from a business challenge. And know how to drive data projects and effectively communicate to technical and non-technical stakeholders. I have a strong record of problem solving and working under pressure.
#
# I have experience leading teams in my previous job. I have provided guidance and support in the use of statistical methodology and building data analysis pipelines, and believe in fostering a collaborative and supportive environment where my mentees feel comfortable asking questions, seeking guidance, and sharing their ideas and insights.
#
#
# Show you understand the amount of responsibilities you have:
#
# I understand that as a lead data analyst, I would directly be reporting to the director of advanced analytics and I would have a huge amount of responsibility and accountability to deliver consistently and help CRICO achieve its business objectives.
# I think over the years, I have gained the necessary skills required to hit the ground running as a manager.
# Overall, my experience so far has taught me leadership abilities, including managing a team, communicating effectively, motivating my team to get them to achieve consistent results
#
# What are your long term career goals?
# My long-term career goal is to take on a leadership role in data analytics and this Lead Data Analyst position aligns perfectly with that goal. I am very interested in this role as it offers me an opportunity to mentor and guide junior analysts, be a key member of the team in driving operational, business, and patient safety related decisions - The learnings and the impact that I can make in this role is unparalleled. and have a direct reporting line to the Head of Advanced Analytics- I will get ample of opportunities and mentorship for . I am really excited about this role and the opportunity to develop my skills in data analysis and leadership, while also contributing to the mission of creating safest care environments for both patients and doctors.
#
# What do you understand about the role?
# When explaining the role to an interviewer, you can highlight the key responsibilities and how they align with your skills and experience. Here is an example of how you can explain your understanding of the job description:
# "From the job description, I understand that this role is focused on leveraging data to make operational, business and patient safety-related decisions. As the Lead Data Analyst, I will be responsible for mentoring junior analysts, developing relationships with internal and external stakeholders, generating and executing analytics projects, presenting findings, and identifying and resolving data quality issues. Additionally, I will work closely with the Analytics team and IS department to optimize data structures and analytic tools. From my previous experience in data analysis, I have the skills and knowledge to successfully perform these responsibilities and I am excited about the opportunity for career advancement that this role offers.
#
#
#
# How would you motivate your team?
# Motivation stems from consistently working towards a clear objective or goal -  so I set the standards high and give them an ambitious yet attainable objective. Performance reviews - establishing a clear communication channel, talking to them about their strengths and weaknesses and devising a plan to work on their weaknesses
# Regular team meetings where they are encouraged to come up with their own ideas about how the project should progress. It makes them feel empowered and valued. Also praise them from time to time. On one hand I will communicate challenge areas and will direct them but I will also praise them when needed.
#
# Tell me about a time you demonstrated leadership abilities
#
# I have had numerous opportunities to demonstrate leadership skills in pervious job. One instance that comes to mind is when I was leading a team of data analysts on a project with a fortune 100 networking hardware company. It was a b2b company. The quality of their customer DB was deteriorating. Sales rep would enter names of persons or addresses instead of the company name.
#
# We were tasked with coming up with a data-driven approach for improving the quality of their customer database. In this project, we built a model which can identify a whether the name entered by sales rep is valid or invalid. And develop recommendations for a correct party name using BERT-based NER upon entering a wrong name.
#
# Firstly, I myself took the time to clearly understand the business problem and outline the project goals and objectives.
#
# I believe in fostering a collaborative work environment where all members feel empowered to ask questions, share their ideas and give feedback. I set up a meeting with the team to brainstorm ideas. I clearly communicated goals and expectations. Everyone put forth their suggestions for the project plan. I delegated tasks and provided guidance to the team in developing the data preprocessing and modelling pipelines. Also took the lead in tuning and evaluating the model.
#
# Throughout the project, I maintained an open communication channel with the stakeholders to communicate our progress or bottlenecks. I leveraged project management tools like teamwork and confluence to track the progress of tasks. I coordinated the project timeline with a project manager.
#
# Finally, the team was able to deliver the model well on time and it was well received by the clients.
# (Optional - Infact, this project was one of the most impactful that quarter for the company and my team was awarded the spot award which is given to 2-3 teams per quarter)
#
# Overall, I was able to showcase my leadership abilities, including managing a team, communicating effectively, motivating my team to get them to achieve consistent results
#
#
# What is your leadership style?
#
# My natural leadership style is leading by example - it is a style where you model the behavior you want to see in your team members
# Having said that, I am a flexible and can adapt to different leadership styles if need be. Knowing the team members and the culture of the company what leadership style do you think will lead to most success here at CRICO?
#
# Tell me about a time you solved a difficult problem
# S - We were working with a fortune 100 leading networking hardware company. For context, whenever there’s an issue with the devices their customers can go online and file a report and their business challenge was that the customer support engineers were taking too long to resolve the service request and their customers were complaining about bad customer experience.
# T - We needed to come up with a data-driven solution to reduce the turnaround time.
# A - This was a very challenging project because it did not have a straightforward solution - that the data is available in nice tabular format and you fit a linear regression model and solve. We had to spend a significant amount of time understanding the business problem. This involved working with SMEs. Once the problem is well defined and
# R -
#
#
# Teamwork questions
# What are the qualities of good teamwork?
# In particular, there are 4 really important skills and qualities for good
# teamwork:
# 1. Communication - establishing a clear line of communication. communicating effectively through verbal or written mediums and being a good listener. And being a good listener - Being able to LISTEN to everyone during team meetings. Being open to feedback and ideas of their teammates.
# 2. Following a plan of action and staying organized - delegating tasks according to everyone’s strengths and keeping track of the timelines through some project management softwares such as confluence teamwork
# 3. You also have to be ADAPTABLE & FLEXIBLE - Data scientists should be able to adapt to changing circumstances and pivot their approach as needed. This may involve learning new skills or technologies, or shifting focus to different tasks as priorities change.
# 4. You must also MOTIVATE & SUPPORT your team colleagues and finally,
# always look to IMPROVE AND DEVELOP as a team and LEARN FROM
# EVERY EXPERIENCE you encounter
#
# Tell me about a time you worked well as part of a team?
# As a data scientist, I have worked as part of a team on many occasions, one project that stands out to me is
# S - when we were working with a Fortune 100 networking hardware company to develop a recommender system. Customer engineers were spending 2-3 hrs every day researching relevant past service requests. Our goal was to reduce this time.
# T - I worked closely with the stakeholders, subject matter experts, and other data scientists to gain an in-depth understanding of the business challenge and data.
# A - I was responsible for data preprocessing and experimenting with different NLP models, fine-tuning and evaluating them to check which one performs the best. Throughout the project, we actively collaborated, communicated, shared ideas and seeked feedback to ensure that our work was aligned with the business objectives. This also helped us to stay organized, setting clear goals and deadlines for each sprint.
# R - Our team was able to deliver the recommendation engine which reduced the turnaround time of engineers by 50%, leading to a significant improvement in customer experience. Our ability to work as a team was key to finding success in this complex project.
#
# Tell me about a time you didn’t have enough data to make the right decision
#
# Suppose a data scientist is working on a project to predict customer churn for a telecom company. After analyzing the data, the data scientist realizes that they don't have enough data to build a reliable predictive model. The data set is small, and it is missing key variables that could be used to predict churn, such as customer satisfaction ratings and demographics.
# In this situation, the data scientist has a few options. They could try to gather more data to improve the model's accuracy, such as by conducting a survey or using external data sources. They could also try to identify the most important variables to include in the model and focus on improving the quality of those variables, even if the data set is still small.
# Alternatively, the data scientist could decide to report their findings to the stakeholders and recommend that more data be collected before proceeding with the project. This could involve explaining the limitations of the current data set and the potential impact on the model's accuracy, and proposing a plan for collecting additional data.
# Ultimately, the decision will depend on the specific goals and constraints of the project, as well as the resources and time available. By carefully considering their options and communicating clearly with stakeholders, the data scientist can make the best decision given the available data.
#
# How do you work under pressure?
#
#
#
# How do you Prioritize your work?
# Prioritizing your work is very important for achieving your deliverables within deadlines. I always prioritize the tasks in order of the needs of the business.
#
# 1. Prioritize by business impact: Focus on tasks that will have the most significant impact on the business or organization, such as tasks that will improve revenue or customer satisfaction.
# 2. Prioritize by dependencies: Identity which tasks are dependent on other tasks and prioritize those that need to be completed first in order to move forward with other tasks.
# 3. Prioritize by effort vs value: Evaluate the amount of effort required to complete a task versus the value it will provide and prioritize tasks that will have the most impact for the least effort.
#
# Ultimately, the best way to prioritize tasks will depend on the specific project and your team's work environment, so it's important to find a method that works for you and your team.
#
# All deliverables are on track to be completed on schedule.
#
#
# What are your weaknesses?
# I would start by mentioning my strength as my weakness is somewhat related. I consider grit to be my greatest strength - no matter how difficult the task, I believe that I can achieve it. It allows me to stay focused and motivated in the face of setbacks and allows me to execute large challenging projects which require sustained effort.
#
# However, my weakness is that sometimes I get too uncomfortable to ask for help when needed because somewhere at the back of my mind, I used to perceive it as a sign of weakness, but I have learned that asking for help at the right time is a skill that needs to be developed just like any other skill.
#
# I have now changed the narrative from seeing it as a sign of weakness to seeing it as a sign of willingness to learn and grow. I have learned to ask for help by articulating the challenges I am facing and the steps I have already taken to solve it. I believe this is an essential aspect of teamwork and collaboration. It not only improves the outcomes of the project but also help build a stronger relationship with my colleagues.
#
# [Optional]
# Additionally, asking for help can not only improve the quality of my work but also help build stronger relationships with my colleagues. I have been actively working on building my comfort level in asking for help and seeking out the expertise of others. I find that this not only improves the outcome of projects but also allows for a more collaborative and inclusive work environment.
#
# Tell me about a time you made a mistake/Tell me about a time you failed.
# When I started as a data analyst in my career, in my first project, we were working to build a classification model to filter out invalid names from a customer database. I was tasked with running the model on a new dataset and reporting the performance metrics to the client. Unfortunately, I made an error and I emailed the wrong numbers. I later realized that I had missed a step during data cleaning, which led to incorrect performance metrics.
#
# I instantly sent a corrected version of the email and apologized for the oversight.
#
# To prevent this from happening again, I implemented several processes. I made it a point to properly comment the code and started writing documentation for the project from the very beginning, documenting each step of the project and shared with all team members to ensure that everyone was on the same page regarding the technical details of the project, & took feedback.
#
# The clients appreciated that we took accountability, were proactive in rectifying it and worked to maintain transparency throughout the project. This helped us earn their trust quickly and they chose to work with us on another impactful data project the following year.
#
#
# What makes you stand out from other candidates? What can you bring to the role?
#
# There are particularly two things which make me stand out from other candidates:
#
# My knowledge and expertise in data analysis have been built over many years in different organizations and through my education.
#
# I have extensive experience of working in the full life-cycle of data projects in different industries. This cross-sectoral experience as a data scientist combined with my education has helped me develop a strong analytical mindset combined with business acumen. I am able to identify opportunities in the business where analytics can create an impact.
#
# I am able to effectively formulate an analytical or data science problem from a business challenge.
# And know how to drive data projects and effectively communicate to technical and non-technical stakeholders. I have a strong record of problem solving and working under pressure.
#
# I have experience leading teams in my previous job. I have provided guidance and support in the use of statistical methodology and building data analysis pipelines, and believe in fostering a collaborative and supportive environment where my mentees feel comfortable asking questions, seeking guidance, and sharing their ideas and insights.
#
# My greatest strength is grit - no matter how difficult the task is, I believe I am capable with achieving it with enough practice and time. It allows me to stay focused and motivated while working on large challenging projects which require sustained effort.
